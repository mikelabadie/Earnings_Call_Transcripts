# %% [markdown]
# ## Read Call Pickle and Build Meta-data and Text DataFrames

# %%
from IPython.display import clear_output

# import the call dataset
import pandas as pd
import numpy as np
import pickle
import os

from google.colab import drive
drive.mount('/content/gdrive')

if os.path.exists("/content/gdrive/My Drive/School/DATS 6450 - NLP/Project/ProcessedCallsPickleUpdated_v2"):
    pfile = open("/content/gdrive/My Drive/School/DATS 6450 - NLP/Project/ProcessedCallsPickleUpdated_v2", "rb")
    calls = pickle.load(pfile)                      
    pfile.close()
    
df_metadata = calls["metadata"]
df_text = calls["text"]

print("Metadata Shape:",df_metadata.shape, "Text Shape:",df_text.shape)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Metadata Shape: (5101, 6) Text Shape: (640132, 11)

# %% [markdown]
# #### Mean Num Prepared Remarks Paragraphs per Call

# %%
df_metadata.shape[0]
prepared_remarks_count = df_text[(df_text["Call Section"]=="Prepared Remarks")&(df_text["Speaker"]!="Operator")].shape[0]
prepared_remarks_count/df_metadata.shape[0]
# Out:
# 40.87433836502647

# %% [markdown]
# ## Tools to Build Corpus

# %%
! pip install pyLDAvis
clear_output()

# %%
import numpy as np
import nltk
nltk.download('wordnet')

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import time

clear_output()

# %% [markdown]
# ## Build Corpus

# %% [markdown]
# #### Get a List of Tickers to Analyze

# %%
ticker_list = ["DNKN","SBUX","MCD","QSR","YUM","BLMN","EAT","CMG","CBRL","DRI","DPZ","JACK","PZZA","TXRH","CAKE",
              "WEN","BH","BH","BJRI","BOJA","TAST","CHUY","PLAY","DFRG","TACO","DENN","DIN","LOCO","FRGI","PBPB",
              "RRGB","RUTH","SHAK","SONC","HABT","WING","ZOES","ARKR","BURG","SAUC","DAVE","FAT","BDL","GTIM",
              "KONA","JAX","JMBA","LUB","NATH","NDLS","FRSH","RAVE","STKS"]

# %%
corpus, call_names, paragraph_nums, corpus_whole_calls, call_names_whole_calls = [], [], [], [], []

#calls_to_use = df_metadata.dropna(subset=["ticker","period","call date"])[0:5000]
calls_to_use = df_metadata[(df_metadata["ticker"].isin(ticker_list))].sort_values(by=["ticker"])

for _, row in calls_to_use.iterrows():
    prepared_remarks = df_text[df_text["Link"]==row["Link"]]
    prepared_remarks = prepared_remarks[(prepared_remarks["Call Section"]=="Prepared Remarks")&(prepared_remarks["Speaker"]!="Operator")]
    
    corpus += list(prepared_remarks["Cleaned Text"])
    call_names += list(prepared_remarks.index)
    paragraph_nums  += list(prepared_remarks["Call Paragraph Num"])
    
    corpus_whole_calls.append(" ".join(list(prepared_remarks["Cleaned Text"])))
    call_names_whole_calls.append(row["ticker"] + " " + row["period"])

# %% [markdown]
# ## Vectors

# %% [markdown]
# #### Find Common Used Phrases at Whole Call Level
# I'm looking to find phrases said on every call.  Particularly, things like "forward looking statements" to help identify phrases that might signify a paragraph is "mandatory".

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity as sklearn_cosine_similarity

vectorizer = CountVectorizer(ngram_range=(2,2), min_df=0.8, binary=True)
X = vectorizer.fit_transform(corpus_whole_calls)
df = pd.DataFrame(data=X.toarray(), index=call_names_whole_calls, columns=vectorizer.get_feature_names())

keywords_by_doc = set(df.columns)

print(keywords_by_doc)
# Out:
# {'long term', 'basis point', 'forward looking', 'looking statement', 'turn call', 'tax rate', 'last year', 'thank you', 'full year', 'per share'}

# %% [markdown]
# #### Find Phrases at Paragraph Level
# I'm looking to find phrases that typically occur at least once, but no more than a few times during a call (like "forward looking statements").

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity as sklearn_cosine_similarity

vectorizer = CountVectorizer(ngram_range=(1,3), min_df=0.02, max_df=0.075, binary=True)
X = vectorizer.fit_transform(corpus)
df = pd.DataFrame(data=X.toarray(), index=call_names, columns=vectorizer.get_feature_names())
df["Paragraph Location"] = paragraph_nums

keywords_by_paragraph = set(df.columns)

print(df.shape, df.columns)
# Out:
# (2940, 455) Index(['10', '100', '11', '12', '13', '14', '15', '16', '17', '18',
#        ...
#        'work', 'working', 'world', 'would', 'year ago', 'year over',
#        'year over year', 'year period', 'you', 'Paragraph Location'],
#       dtype='object', length=455)

# %%
keywords_by_doc.intersection(keywords_by_paragraph)
# Out:
# {'forward looking',
#  'full year',
#  'long term',
#  'looking statement',
#  'per share',
#  'tax rate',
#  'thank you',
#  'turn call'}

# %% [markdown]
# ## KMeans Clustering to Classify Compliance Paragraphs
#
# https://scikit-learn.org/stable/auto_examples/text/plot_document_clustering.html#sphx-glr-auto-examples-text-plot-document-clustering-py

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3)

cols = list(set(df.columns)-set(["Prediction"]))
cols = list(keywords_by_doc.intersection(keywords_by_paragraph))
km.fit(df.loc[:,cols].values)

df["Prediction"] = km.labels_
low_occurence_class = df["Prediction"].value_counts().sort_values().index[0]
compliance_paragraphs = df.loc[df["Prediction"]==low_occurence_class,["Prediction","Paragraph Location"]].index

print(df["Prediction"].value_counts().sort_values())
# Out:
# 2      90
# 1     186
# 0    2664
# Name: Prediction, dtype: int64

# %%
compliance_paragraphs[-100:]
# Out:
# Index(['BJRI Q4 2018 2', 'BJRI Q4 2018 3', 'BJRI Q4 2018 26', 'BJRI Q3 2018 4',
#        'BJRI Q3 2018 5', 'BJRI Q3 2018 6', 'BJRI Q3 2018 31', 'BLMN Q4 2018 3',
#        'BLMN Q3 2018 2', 'CAKE Q3 2018 3', 'CAKE Q4 2018 3', 'CAKE Q4 2018 4',
#        'CAKE Q4 2017 2', 'CBRL Q2 2019 5', 'CBRL Q1 2019 3', 'CBRL Q1 2019 4',
#        'CBRL Q4 2018 4', 'CHUY Q3 2018 3', 'CHUY Q1 2018 2', 'CHUY Q4 2018 2',
#        'CMG Q1 2018 1', 'CMG Q1 2018 2', 'CMG Q4 2018 3', 'CMG Q4 2018 4',
#        'CMG Q3 2018 3', 'CMG Q3 2018 4', 'CMG Q2 2018 2', 'DENN Q4 2018 3',
#        'DFRG Q4 2018 3', 'DIN Q4 2017 3', 'DIN Q4 2017 4', 'DNKN Q4 2018 1',
#        'DNKN Q3 2018 3', 'DPZ Q4 2018 3', 'DPZ Q3 2018 5', 'DRI Q2 2019 1',
#        'DRI Q1 2019 1', 'DRI Q4 2018 1', 'EAT Q2 2019 4', 'EAT Q1 2019 5',
#        'FRGI Q3 2018 4', 'FRGI Q4 2018 2', 'FRGI Q4 2018 3', 'JACK Q1 2019 5',
#        'JACK Q4 2018 3', 'LOCO Q4 2018 3', 'MCD Q2 2018 3', 'MCD Q4 2018 2',
#        'MCD Q3 2018 3', 'MCD Q4 2017 2', 'NDLS Q2 2018 3', 'NDLS Q2 2018 4',
#        'NDLS Q2 2018 5', 'NDLS Q2 2018 9', 'PBPB Q4 2018 2', 'PBPB Q4 2018 3',
#        'PLAY Q3 2018 3', 'PLAY Q1 2018 3', 'PLAY Q1 2018 4', 'PLAY Q4 2017 4',
#        'PZZA Q4 2018 3', 'QSR Q4 2018 5', 'QSR Q3 2018 2', 'RUTH Q4 2018 3',
#        'RUTH Q2 2018 2', 'SBUX Q4 2018 4', 'SBUX Q1 2019 2', 'SBUX Q1 2019 3',
#        'SBUX Q4 2017 2', 'SBUX Q3 2018 2', 'SBUX Q3 2018 3', 'SBUX Q2 2018 2',
#        'SBUX Q2 2018 3', 'SBUX Q1 2018 2', 'SHAK Q4 2018 4', 'TACO Q3 2018 1',
#        'TACO Q3 2018 2', 'TAST Q4 2018 4', 'TXRH Q2 2018 4', 'TXRH Q1 2018 1',
#        'TXRH Q1 2018 2', 'TXRH Q4 2018 2', 'TXRH Q4 2018 3', 'TXRH Q3 2018 3',
#        'WEN Q4 2018 2', 'WEN Q3 2018 2', 'WING Q3 2018 3', 'WING Q4 2018 5',
#        'YUM Q3 2017 1', 'YUM Q3 2018 3'],
#       dtype='object')

# %% [markdown]
# ## Call Links

# %%
print(calls_to_use.index.values)
# Out:
# ['https://www.fool.com/earnings/call-transcripts/2019/02/22/bjs-restaurants-inc-bjri-q4-2018-earnings-conferen.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/30/bjs-restaurants-inc-bjri-q3-2018-earnings-conferen.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/14/bloomin-brands-inc-blmn-q4-2018-earnings-conferenc.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/30/bloomin-brands-blmn-q3-2018-earnings-conference-ca.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/30/cheesecake-factory-inc-cake-q3-2018-earnings-confe.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/20/cheesecake-factory-inc-cake-q4-2018-earnings-confe.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/02/21/the-cheesecake-factory-incorporated-cake-q4-2017-e.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/26/cracker-barrel-old-country-store-inc-cbrl-q2-2019.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/27/cracker-barrel-old-country-store-cbrl-q1-2019-earn.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/09/18/cracker-barrel-old-country-store-inc-cbrl-q4-2018.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/06/chuys-holdings-inc-chuy-q3-2018-earnings-conferenc.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/05/09/chuys-holdings-chuy-q1-2018-earnings-conference-ca.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/03/07/chuys-holdings-inc-chuy-q4-2018-earnings-conferenc.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/04/26/chipotle-mexican-grill-cmg-q1-2018-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/06/chipotle-mexican-grill-inc-cmg-q4-2018-earnings-co.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/26/chipotle-mexican-grill-inc-cmg-q3-2018-earnings-co.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/07/27/chipotle-mexican-grill-cmg-q2-2018-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/12/dennys-corp-denn-q4-2018-earnings-conference-call.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/03/12/del-friscos-restaurant-group-inc-dfrg-q4-2018-earn.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/02/21/dineequity-din-q4-2017-earnings-conference-call-tr.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/07/dunkin-brands-group-inc-dnkn-q4-2018-earnings-conf.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/26/dunkin-brands-group-inc-dnkn-q3-2018-earnings-conf.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/21/dominos-pizza-inc-dpz-q4-2018-earnings-conference.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/16/dominos-pizza-inc-dpz-q3-2018-earnings-conference.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/12/18/darden-restaurants-inc-dri-q2-2019-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/09/20/darden-restaurants-inc-dri-q1-2019-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/06/21/darden-restaurants-inc-dri-q4-2018-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/01/29/brinker-international-inc-eat-q2-2019-earnings-con.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/30/brinker-international-inc-eat-q1-2019-earnings-con.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/05/fiesta-restaurant-group-inc-frgi-q3-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/25/fiesta-restaurant-group-inc-frgi-q4-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/28/the-habit-restaurants-inc-habt-q4-2018-earnings-co.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/21/jack-in-the-box-inc-jack-q1-2019-earnings-conferen.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/20/jack-in-the-box-inc-jack-q4-2018-earnings-conferen.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/03/07/el-pollo-loco-holdings-inc-loco-q4-2018-earnings-c.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/07/26/mcdonalds-corporation-mcd-q2-2018-earnings-confere.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/01/30/mcdonalds-corp-mcd-q4-2018-earnings-conference-cal.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/23/mcdonalds-corp-mcd-q3-2018-earnings-conference-cal.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/01/31/mcdonalds-mcd-q4-2017-earnings-conference-call-tra.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/04/30/mcdonalds-corporation-mcd-q1-2018-earnings-confere.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/07/20/noodles-co-ndls-q2-2018-earnings-conference-call-t.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/25/potbelly-corp-pbpb-q4-2018-earnings-conference-cal.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/12/11/dave-busters-entertainment-inc-play-q3-2018-earnin.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/06/11/dave-busters-entertainment-inc-play-q1-2018-earnin.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/04/05/play-q4-2017-earnings-conference-call-transcript.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/06/papa-johns-international-inc-pzza-q3-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/27/papa-johns-international-inc-pzza-q4-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/11/restaurant-brands-international-inc-qsr-q4-2018-ea.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/25/restaurant-brands-international-qsr-q3-2018-earnin.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/27/red-robin-gourmet-burgers-rrgb-q4-2018-earnings-co.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/08/22/red-robin-gourmet-burgers-rrgb-q2-2018-earnings-co.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/06/red-robin-gourmet-burgers-inc-rrgb-q3-2018-earning.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/22/ruths-hospitality-group-inc-ruth-q4-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/08/13/ruths-hospitality-group-ruth-q2-2018-earnings-conf.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/01/starbucks-corp-sbux-q4-2018-earnings-conference-ca.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/01/25/starbucks-sbux-q1-2019-earnings-conference-call-tr.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2017/11/03/starbucks-corp-sbux-q4-2017-earnings-conference-ca.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/07/26/starbucks-corporation-sbux-q3-2018-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/04/28/starbucks-sbux-q2-2018-earnings-conference-call-tr.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/01/25/starbucks-corporation-sbux-q1-2018-earnings-confer.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/26/shake-shack-inc-shak-q4-2018-earnings-conference-c.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/03/29/sonic-sonc-q2-2018-earnings-conference-call-transc.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/17/del-taco-restaurants-taco-q3-2018-earnings-confere.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/27/carrols-restaurant-group-inc-tast-q4-2018-earnings.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/07/31/texas-roadhouse-txrh-q2-2018-earnings-conference-c.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/05/01/texas-roadhouse-txrh-q1-2018-earnings-conference-c.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/20/texas-roadhouse-txrh-q4-2018-earnings-conference-c.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/29/texas-roadhouse-inc-txrh-q3-2018-earnings-conferen.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/21/the-wendys-co-wen-q4-2018-earnings-conference-call.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/11/07/the-wendys-co-wen-q3-2018-earnings-conference-call.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/29/wingstop-inc-wing-q3-2018-earnings-conference-call.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2019/02/27/wingstop-inc-wing-q4-2018-earnings-conference-call.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2017/11/02/yum-brands-inc-yum-q3-2017-earnings-conference-cal.aspx'
#  'https://www.fool.com/earnings/call-transcripts/2018/10/31/yum-brands-inc-yum-q3-2018-earnings-conference-cal.aspx']
